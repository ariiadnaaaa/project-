# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# БАРИСТА
def clean_data(data):
     cleaned_data = []
     for item in data:
        try:
           salary = item['salary'].replace('\u2009', '').replace('\xa0', ' ')
           experience = item['experience'].replace('\xa0', ' ')
           cleaned_data.append({'salary': salary, 'experience': experience})
        except TypeError:
           continue
     return cleaned_data
# Попросил чат-гпт написать функцию, которая бы приводила информацию в нормальный вид, и добавил try / except, чтобы избежать проблем с пустыми элементами списка

all_candidates = []

for i in range(20): # Берем первые 20 страниц
  html = f'https://hh.ru/search/resume?area=1&exp_period=all_time&job_search_status=active_search&job_search_status=looking_for_offers&logic=normal&no_magic=true&order_by=relevance&ored_clusters=true&pos=full_text&search_period=30&text=%D0%B1%D0%B0%D1%80%D0%B8%D1%81%D1%82%D0%B0+%D0%B2+%D0%BA%D0%BE%D1%84%D0%B5%D0%B9%D0%BD%D1%8E&items_on_page=20&searchSessionId=59616e58-395a-4e21-8c7c-631a268c021f&page={i}'
  response = requests.get(html, headers={"User-Agent": "Mozilla/5.0"}) # Получаем html
  soup = BeautifulSoup(response.content, 'html.parser') # Создаем объект BeautifulSoup

  candidates = [] # Список профилей кандидатов
  candidates.append(None) # Чтобы потом не было проблем с "if candidate_data == candidates[-1]:"

  for candidate in soup.find_all('div'):

     salary_element = candidate.find('div', class_='magritte-text___pbpft_3-0-30 magritte-text_style-primary___AQ7MW_3-0-30 magritte-text_typography-subtitle-2-semibold___3q3c-_3-0-30') # Вытаскиваем з/п
     experience_element = candidate.find('div', class_='content--vAUqut0YCUxg4xgv') # Вытаскиваем информацию об опыте кандидатов

     if salary_element and experience_element:
         candidate_data = {'salary': salary_element.text.strip(), 'experience': experience_element.text.strip()} # Добавляем в итоговый список словарь с информацией о кандидате
         if candidate_data == candidates[-1]:
           pass
         elif '\u20BD' in candidate_data['salary']:
           candidates.append(candidate_data)
     # Если есть информация об опыте и з/п, то добавляем в список кандидатов
     # Была проблема, что информация об одном и том же кандидате выводится несколько раз подряд, поэтому проверяем, что добавляемы элемент отличен от прошлого добавленного
     # Некоторые слегка обнаглевшие люди указывают з/п в долларах и евро, удаляем их из списка

  final_data = clean_data(candidates) # Приводим в нормальный вид
  all_candidates.extend(final_data) # Перевод листа словарей в датафреймм написал чат-гпт, каюсь

  # for item in final_data:
  #    print(item)

df_barista = pd.DataFrame(all_candidates)
df_barista = df_barista.transpose()
display(df_barista)
# Out:
#                          0                1                2    \
# salary               65000 ₽         150000 ₽          50000 ₽
# experience  5 лет 11 месяцев  13 лет 3 месяца  2 года 4 месяца
#
#                        3                4         5                  6    \
# salary            150000 ₽         120000 ₽  100000 ₽            90000 ₽
# experience  10 лет 1 месяц  8 лет 8 месяцев     7 лет  3 года 10 месяцев
#
#                          7         8                9    ...  \
# salary              115000 ₽  150000 ₽          80000 ₽  ...
# experience  12 лет 7 месяцев    11 лет  6 лет 8 месяцев  ...
#
#                          97             98              99               100  \
# salary               80000 ₽       120000 ₽         80000 ₽         100000 ₽
# experience  10 лет 9 месяцев  9 лет 1 месяц  10 лет 1 месяц  4 года 2 месяца
#
#                    101             102              103               104  \
# salary         50000 ₽        150000 ₽         150000 ₽          400000 ₽
# experience  10 месяцев  6 лет 4 месяца  6 лет 5 месяцев  14 лет 6 месяцев
#
#                          105               106
# salary              120000 ₽          250000 ₽
# experience  6 лет 10 месяцев  12 лет 5 месяцев
#
# [2 rows x 107 columns]

# %% [markdown]
#  **Далее идейно такой же код, просто меняем ссылки и учитываем особенности страниц**

# %%
# АДМИНИСТРАТОР ЗАЛА
# КРИТЕРИИ: 1) полная занятость; 2) полный день; 3) специализации: администратор или менеджер ресторана

def clean_data(data):
     cleaned_data = []
     for item in data:
        try:
           salary = item['salary'].replace('\u2009', '').replace('\xa0', ' ')
           experience = item['experience'].replace('\xa0', ' ')
           cleaned_data.append({'salary': salary, 'experience': experience})
        except TypeError:
           continue
     return cleaned_data
# Попросил чат-гпт написать функцию, которая бы приводила информацию в нормальный вид, и добавил try / except, чтобы избежать проблем с пустыми элементами списка

all_candidates = []

for i in range(20): # Берем первые 20 страниц
  html = f'https://hh.ru/search/resume?search_period=0&order_by=relevance&logic=normal&pos=full_text&exp_period=all_time&area=1&employment=full&filter_exp_period=all_time&job_search_status=active_search&job_search_status=looking_for_offers&job_search_status=unknown&professional_role=8&professional_role=74&relocation=living_or_relocation&schedule=fullDay&text=администратор+в+кофейню&gender=unknown&page={i}&searchSessionId=3636c17e-0578-45ff-ba81-15591c276518'
  response = requests.get(html, headers={"User-Agent": "Mozilla/5.0"}) # Получаем html
  soup = BeautifulSoup(response.content, 'html.parser') # Создаем объект BeautifulSoup

  candidates = [] # Список профилей кандидатов
  candidates.append(None) # Чтобы потом не было проблем с "if candidate_data == candidates[-1]:"

  for candidate in soup.find_all('div'):

     salary_element = candidate.find('div', class_='magritte-text___pbpft_3-0-30 magritte-text_style-primary___AQ7MW_3-0-30 magritte-text_typography-subtitle-2-semibold___3q3c-_3-0-30') # Вытаскиваем з/п
     experience_element = candidate.find('div', class_='content--vAUqut0YCUxg4xgv') # Вытаскиваем информацию об опыте кандидатов

     if salary_element and experience_element:
         candidate_data = {'salary': salary_element.text.strip(), 'experience': experience_element.text.strip()} # Добавляем в итоговый список словарь с информацией о кандидате
         if candidate_data == candidates[-1]:
           pass
         elif '\u20BD' in candidate_data['salary']:
           candidates.append(candidate_data)
     # Если есть информация об опыте и з/п, то добавляем в список кандидатов
     # Была проблема, что информация об одном и том же кандидате выводится несколько раз подряд, поэтому проверяем, что добавляемы элемент отличен от прошлого добавленного
     # Некоторые слегка обнаглевшие люди указывают з/п в долларах и евро, удаляем их из списка

  final_data = clean_data(candidates) # Приводим в нормальный вид
  all_candidates.extend(final_data) # Перевод листа словарей в датафреймм написал чат-гпт, каюсь

  # for item in final_data:
  #    print(item)

df_manager = pd.DataFrame(all_candidates)
df_manager = df_manager.transpose()
display(df_manager)

# %%
# УБОРКА
# КРИТЕРИИ: 1) живет в регионе; 2) полный день; 3) полная занятость 4) специализации: уборщик / уборщица 5) з/п от 40000 (чтобы избежать нерелевантных предложений)

def clean_data(data):
     cleaned_data = []
     for item in data:
        try:
           salary = item['salary'].replace('\u2009', '').replace('\xa0', ' ')
           experience = item['experience'].replace('\xa0', ' ')
           cleaned_data.append({'salary': salary, 'experience': experience})
        except TypeError:
           continue
     return cleaned_data
# Попросил чат-гпт написать функцию, которая бы приводила информацию в нормальный вид, и добавил try / except, чтобы избежать проблем с пустыми элементами списка

all_candidates = []

for i in range(20): # Берем первые 20 страниц
  html = f'https://hh.ru/search/resume?isDefaultArea=true&ored_clusters=true&order_by=relevance&search_period=0&logic=normal&pos=full_text&exp_period=all_time&area=1&employment=full&filter_exp_period=all_time&job_search_status=looking_for_offers&job_search_status=active_search&job_search_status=unknown&label=only_with_salary&professional_role=130&relocation=living&schedule=fullDay&text=уборщица+помещений&salary_from=40000&gender=unknown&page={i}&searchSessionId=5b744ea5-5b2a-4df1-ab68-e8af1a445272'
  response = requests.get(html, headers={"User-Agent": "Mozilla/5.0"}) # Получаем html
  soup = BeautifulSoup(response.content, 'html.parser') # Создаем объект BeautifulSoup

  candidates = [] # Список профилей кандидатов
  candidates.append(None) # Чтобы потом не было проблем с "if candidate_data == candidates[-1]:"

  for candidate in soup.find_all('div'):

     salary_element = candidate.find('div', class_='magritte-text___pbpft_3-0-30 magritte-text_style-primary___AQ7MW_3-0-30 magritte-text_typography-subtitle-2-semibold___3q3c-_3-0-30') # Вытаскиваем з/п
     experience_element = candidate.find('div', class_='content--vAUqut0YCUxg4xgv') # Вытаскиваем информацию об опыте кандидатов

     if salary_element and experience_element:
         candidate_data = {'salary': salary_element.text.strip(), 'experience': experience_element.text.strip()} # Добавляем в итоговый список словарь с информацией о кандидате
         if candidate_data == candidates[-1]:
           pass
         elif '\u20BD' in candidate_data['salary']:
           candidates.append(candidate_data)
     # Если есть информация об опыте и з/п, то добавляем в список кандидатов
     # Была проблема, что информация об одном и том же кандидате выводится несколько раз подряд, поэтому проверяем, что добавляемы элемент отличен от прошлого добавленного

  final_data = clean_data(candidates) # Приводим в нормальный вид
  all_candidates.extend(final_data) # Перевод листа словарей в датафреймм написал чат-гпт, каюсь

  # for item in final_data:
  #    print(item)

df_cleaning = pd.DataFrame(all_candidates)
df_cleaning = df_cleaning.transpose()
display(df_cleaning)
# Out:
# {'salary': '40000 ₽', 'experience': '11 лет 6 месяцев'}
# {'salary': '45000 ₽', 'experience': '15 лет 9 месяцев'}
# {'salary': '70000 ₽', 'experience': '5 лет 4 месяца'}
# {'salary': '40000 ₽', 'experience': '24 года 2 месяца'}
# {'salary': '40000 ₽', 'experience': '6 лет 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '4 года'}
# {'salary': '40000 ₽', 'experience': '28 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '16 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '7 лет 8 месяцев'}
# {'salary': '50000 ₽', 'experience': '15 лет 9 месяцев'}
# {'salary': '40000 ₽', 'experience': '6 лет 8 месяцев'}
# {'salary': '70000 ₽', 'experience': '12 лет 9 месяцев'}
# {'salary': '75000 ₽', 'experience': '5 лет 1 месяц'}
# {'salary': '40000 ₽', 'experience': '10 лет 7 месяцев'}
# {'salary': '40000 ₽', 'experience': '25 лет 3 месяца'}
# {'salary': '45000 ₽', 'experience': '5 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '30 лет 11 месяцев'}
# {'salary': '40000 ₽', 'experience': '18 лет 11 месяцев'}
# {'salary': '40000 ₽', 'experience': '10 лет 3 месяца'}
# {'salary': '45000 ₽', 'experience': '9 лет 1 месяц'}
# {'salary': '60000 ₽', 'experience': '14 лет'}
# {'salary': '40000 ₽', 'experience': '8 лет'}
# {'salary': '70000 ₽', 'experience': '13 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '11 лет 2 месяца'}
# {'salary': '40000 ₽', 'experience': '15 лет 9 месяцев'}
# {'salary': '40000 ₽', 'experience': '3 года 4 месяца'}
# {'salary': '40000 ₽', 'experience': '7 лет 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '16 лет 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '1 год 7 месяцев'}
# {'salary': '50000 ₽', 'experience': '19 лет 2 месяца'}
# {'salary': '45000 ₽', 'experience': '23 года'}
# {'salary': '55000 ₽', 'experience': '11 лет 3 месяца'}
# {'salary': '60000 ₽', 'experience': '14 лет 8 месяцев'}
# {'salary': '100000 ₽', 'experience': '15 лет 4 месяца'}
# {'salary': '40000 ₽', 'experience': '8 лет 2 месяца'}
# {'salary': '40000 ₽', 'experience': '15 лет 7 месяцев'}
# {'salary': '45000 ₽', 'experience': '11 лет 1 месяц'}
# {'salary': '80000 ₽', 'experience': '13 лет 5 месяцев'}
# {'salary': '50000 ₽', 'experience': '16 лет 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '35 лет 8 месяцев'}
# {'salary': '50000 ₽', 'experience': '21 год 11 месяцев'}
# {'salary': '45000 ₽', 'experience': '35 лет 8 месяцев'}
# {'salary': '50000 ₽', 'experience': '8 лет 6 месяцев'}
# {'salary': '40000 ₽', 'experience': '6 лет 2 месяца'}
# {'salary': '70000 ₽', 'experience': '3 месяца'}
# {'salary': '80000 ₽', 'experience': '10 лет 4 месяца'}
# {'salary': '40000 ₽', 'experience': '4 года 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '13 лет 4 месяца'}
# {'salary': '40000 ₽', 'experience': '5 лет 1 месяц'}
# {'salary': '40000 ₽', 'experience': '22 года 8 месяцев'}
# {'salary': '60000 ₽', 'experience': '3 года 10 месяцев'}
# {'salary': '70000 ₽', 'experience': '13 лет 8 месяцев'}
# {'salary': '45000 ₽', 'experience': '25 лет 3 месяца'}
# {'salary': '50000 ₽', 'experience': '7 лет 9 месяцев'}
# {'salary': '75000 ₽', 'experience': '18 лет 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '16 лет'}
# {'salary': '40000 ₽', 'experience': '28 лет 6 месяцев'}
# {'salary': '50000 ₽', 'experience': '7 лет 8 месяцев'}
# {'salary': '50000 ₽', 'experience': '3 года 8 месяцев'}
# {'salary': '80000 ₽', 'experience': '7 лет 3 месяца'}
# {'salary': '45000 ₽', 'experience': '7 лет'}
# {'salary': '45000 ₽', 'experience': '5 лет 3 месяца'}
# {'salary': '50000 ₽', 'experience': '1 год 9 месяцев'}
# {'salary': '45000 ₽', 'experience': '7 лет 1 месяц'}
# {'salary': '40000 ₽', 'experience': '9 лет'}
# {'salary': '70000 ₽', 'experience': '11 лет 10 месяцев'}
# {'salary': '45000 ₽', 'experience': '10 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': 'Исполнительность'}
# {'salary': '42500 ₽', 'experience': '8 лет 4 месяца'}
# {'salary': '40000 ₽', 'experience': '6 лет 10 месяцев'}
# {'salary': '50000 ₽', 'experience': 'Исполнительность'}
# {'salary': '50000 ₽', 'experience': '10 лет'}
# {'salary': '50000 ₽', 'experience': '19 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '31 год 1 месяц'}
# {'salary': '50000 ₽', 'experience': '16 лет 2 месяца'}
# {'salary': '50000 ₽', 'experience': '7 лет 2 месяца'}
# {'salary': '40000 ₽', 'experience': '14 лет 3 месяца'}
# {'salary': '50000 ₽', 'experience': '20 лет 10 месяцев'}
# {'salary': '70000 ₽', 'experience': '23 года 2 месяца'}
# {'salary': '40000 ₽', 'experience': '9 месяцев'}
# {'salary': '40000 ₽', 'experience': '2 года 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '9 месяцев'}
# {'salary': '40000 ₽', 'experience': '17 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '9 лет 7 месяцев'}
# {'salary': '100000 ₽', 'experience': '12 лет 2 месяца'}
# {'salary': '60000 ₽', 'experience': '22 года 11 месяцев'}
# {'salary': '50000 ₽', 'experience': '7 лет 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '26 лет 8 месяцев'}
# {'salary': '60000 ₽', 'experience': '3 года 9 месяцев'}
# {'salary': '45000 ₽', 'experience': 'Имею достаточный объем знаний для создания и поддержания комфортного микроклимата в офисе. Знание эт'}
# {'salary': '45000 ₽', 'experience': '7 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '2 года 7 месяцев'}
# {'salary': '40000 ₽', 'experience': '13 лет 2 месяца'}
# {'salary': '60000 ₽', 'experience': '10 лет 8 месяцев'}
# {'salary': '50000 ₽', 'experience': '2 года 1 месяц'}
# {'salary': '50000 ₽', 'experience': '34 года 3 месяца'}
# {'salary': '85000 ₽', 'experience': '27 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '13 лет 2 месяца'}
# {'salary': '55000 ₽', 'experience': '2 года 10 месяцев'}
# {'salary': '70000 ₽', 'experience': '1 год 3 месяца'}
# {'salary': '60000 ₽', 'experience': '2 года 2 месяца'}
# {'salary': '40000 ₽', 'experience': '33 года 1 месяц'}
# {'salary': '50000 ₽', 'experience': '14 лет 7 месяцев'}
# {'salary': '70000 ₽', 'experience': '32 года 7 месяцев'}
# {'salary': '45000 ₽', 'experience': '14 лет 3 месяца'}
# {'salary': '50000 ₽', 'experience': '4 года 11 месяцев'}
# {'salary': '45000 ₽', 'experience': '17 лет 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '10 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '3 месяца'}
# {'salary': '50000 ₽', 'experience': '23 года 6 месяцев'}
# {'salary': '50000 ₽', 'experience': '36 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '13 лет 10 месяцев'}
# {'salary': '45000 ₽', 'experience': '28 лет 9 месяцев'}
# {'salary': '40000 ₽', 'experience': '11 лет 1 месяц'}
# {'salary': '40000 ₽', 'experience': '10 лет 8 месяцев'}
# {'salary': '50000 ₽', 'experience': '6 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '22 года 5 месяцев'}
# {'salary': '45000 ₽', 'experience': '7 лет 5 месяцев'}
# {'salary': '65000 ₽', 'experience': '27 лет 9 месяцев'}
# {'salary': '50000 ₽', 'experience': '17 лет 2 месяца'}
# {'salary': '60000 ₽', 'experience': '4 года'}
# {'salary': '40000 ₽', 'experience': '22 года 7 месяцев'}
# {'salary': '40000 ₽', 'experience': '36 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '9 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '7 лет 1 месяц'}
# {'salary': '100000 ₽', 'experience': '10 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '8 лет 9 месяцев'}
# {'salary': '70000 ₽', 'experience': '14 лет 3 месяца'}
# {'salary': '70000 ₽', 'experience': '8 лет 2 месяца'}
# {'salary': '90000 ₽', 'experience': '5 лет 4 месяца'}
# {'salary': '70000 ₽', 'experience': '14 лет 6 месяцев'}
# {'salary': '90000 ₽', 'experience': '5 лет 11 месяцев'}
# {'salary': '45000 ₽', 'experience': '4 года 11 месяцев'}
# {'salary': '45000 ₽', 'experience': '43 года 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '11 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '1 год 1 месяц'}
# {'salary': '40000 ₽', 'experience': '5 лет 9 месяцев'}
# {'salary': '50000 ₽', 'experience': '16 лет 5 месяцев'}
# {'salary': '80000 ₽', 'experience': '23 года 7 месяцев'}
# {'salary': '40000 ₽', 'experience': '19 лет 2 месяца'}
# {'salary': '45000 ₽', 'experience': '22 года 9 месяцев'}
# {'salary': '40000 ₽', 'experience': '8 лет 2 месяца'}
# {'salary': '40000 ₽', 'experience': '2 года 4 месяца'}
# {'salary': '40000 ₽', 'experience': '9 лет 8 месяцев'}
# {'salary': '49000 ₽', 'experience': '8 лет 2 месяца'}
# {'salary': '50000 ₽', 'experience': '7 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '24 года 7 месяцев'}
# {'salary': '55000 ₽', 'experience': '3 года 3 месяца'}
# {'salary': '50000 ₽', 'experience': '17 лет 3 месяца'}
# {'salary': '50000 ₽', 'experience': '5 лет 1 месяц'}
# {'salary': '40000 ₽', 'experience': '9 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '1 год 7 месяцев'}
# {'salary': '40000 ₽', 'experience': '12 лет 3 месяца'}
# {'salary': '80000 ₽', 'experience': '22 года'}
# {'salary': '40000 ₽', 'experience': '1 год 1 месяц'}
# {'salary': '300000 ₽', 'experience': '1 год 2 месяца'}
# {'salary': '40000 ₽', 'experience': '6 лет 6 месяцев'}
# {'salary': '40000 ₽', 'experience': '10 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '1 год 4 месяца'}
# {'salary': '45000 ₽', 'experience': '15 лет'}
# {'salary': '50000 ₽', 'experience': '15 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '4 года 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '8 месяцев'}
# {'salary': '40000 ₽', 'experience': '8 лет 1 месяц'}
# {'salary': '50000 ₽', 'experience': '13 лет 6 месяцев'}
# {'salary': '40000 ₽', 'experience': '17 лет'}
# {'salary': '60000 ₽', 'experience': '1 год 11 месяцев'}
# {'salary': '50000 ₽', 'experience': '2 года 11 месяцев'}
# {'salary': '65000 ₽', 'experience': '13 лет 1 месяц'}
# {'salary': '55000 ₽', 'experience': '11 лет 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '40 лет 2 месяца'}
# {'salary': '40000 ₽', 'experience': '10 лет 2 месяца'}
# {'salary': '40000 ₽', 'experience': '3 года 11 месяцев'}
# {'salary': '40000 ₽', 'experience': '43 года 6 месяцев'}
# {'salary': '45000 ₽', 'experience': '10 лет 2 месяца'}
# {'salary': '50000 ₽', 'experience': '3 года 7 месяцев'}
# {'salary': '45000 ₽', 'experience': '13 лет 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '16 лет 1 месяц'}
# {'salary': '40000 ₽', 'experience': '3 месяца'}
# {'salary': '50000 ₽', 'experience': '2 года 3 месяца'}
# {'salary': '50000 ₽', 'experience': '13 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '8 лет'}
# {'salary': '40000 ₽', 'experience': '18 лет 1 месяц'}
# {'salary': '40000 ₽', 'experience': '8 лет 8 месяцев'}
# {'salary': '50000 ₽', 'experience': '23 года 3 месяца'}
# {'salary': '45000 ₽', 'experience': '35 лет'}
# {'salary': '40000 ₽', 'experience': '8 лет 4 месяца'}
# {'salary': '40000 ₽', 'experience': '19 лет 11 месяцев'}
# {'salary': '40000 ₽', 'experience': '3 года 11 месяцев'}
# {'salary': '40000 ₽', 'experience': '4 года 8 месяцев'}
# {'salary': '45000 ₽', 'experience': '7 лет 2 месяца'}
# {'salary': '40000 ₽', 'experience': '31 год 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '1 год 2 месяца'}
# {'salary': '40000 ₽', 'experience': '11 лет 3 месяца'}
# {'salary': '45000 ₽', 'experience': '11 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '16 лет 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '18 лет 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '4 года 7 месяцев'}
# {'salary': '50000 ₽', 'experience': '25 лет 1 месяц'}
# {'salary': '40000 ₽', 'experience': '37 лет 7 месяцев'}
# {'salary': '40000 ₽', 'experience': '10 лет 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '9 лет'}
# {'salary': '40000 ₽', 'experience': '7 лет 11 месяцев'}
# {'salary': '45000 ₽', 'experience': '3 года 2 месяца'}
# {'salary': '65000 ₽', 'experience': '9 лет 5 месяцев'}
# {'salary': '40000 ₽', 'experience': '12 лет 7 месяцев'}
# {'salary': '40000 ₽', 'experience': '11 лет'}
# {'salary': '40000 ₽', 'experience': '20 лет 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '9 лет 8 месяцев'}
# {'salary': '45000 ₽', 'experience': '4 года 1 месяц'}
# {'salary': '40000 ₽', 'experience': '5 лет 9 месяцев'}
# {'salary': '40000 ₽', 'experience': '7 лет 7 месяцев'}
# {'salary': '50000 ₽', 'experience': '12 лет 11 месяцев'}
# {'salary': '40000 ₽', 'experience': '7 лет 7 месяцев'}
# {'salary': '40000 ₽', 'experience': '15 лет 11 месяцев'}
# {'salary': '50000 ₽', 'experience': '20 лет 4 месяца'}
# {'salary': '45000 ₽', 'experience': '3 года 10 месяцев'}
# {'salary': '50000 ₽', 'experience': '2 года 10 месяцев'}
# {'salary': '40000 ₽', 'experience': '8 лет 6 месяцев'}
# {'salary': '45000 ₽', 'experience': '5 лет 2 месяца'}
# {'salary': '45000 ₽', 'experience': '7 лет 3 месяца'}
# {'salary': '40000 ₽', 'experience': '6 месяцев'}
# {'salary': '40000 ₽', 'experience': 'работоспособна  •  Работала помощник воспитателя  •  Изготовитель конфет  •  Уборщица служебных помещений'}
# {'salary': '40000 ₽', 'experience': '9 месяцев'}
# {'salary': '40000 ₽', 'experience': '10 лет 8 месяцев'}
# {'salary': '40000 ₽', 'experience': '13 лет 1 месяц'}
# {'salary': '45000 ₽', 'experience': '21 год 5 месяцев'}
# {'salary': '45000 ₽', 'experience': '10 лет'}
# {'salary': '40000 ₽', 'experience': '9 лет 8 месяцев'}
# {'salary': '50000 ₽', 'experience': '25 лет 7 месяцев'}
# {'salary': '50000 ₽', 'experience': '5 лет 7 месяцев'}
# {'salary': '60000 ₽', 'experience': '3 года 1 месяц'}
#       salary        experience
# 0    40000 ₽  11 лет 6 месяцев
# 1    45000 ₽  15 лет 9 месяцев
# 2    70000 ₽    5 лет 4 месяца
# 3    40000 ₽  24 года 2 месяца
# 4    40000 ₽   6 лет 8 месяцев
# ..       ...               ...
# 227  45000 ₽            10 лет
# 228  40000 ₽   9 лет 8 месяцев
# 229  50000 ₽  25 лет 7 месяцев
# 230  50000 ₽   5 лет 7 месяцев
# 231  60000 ₽    3 года 1 месяц
#
# [232 rows x 2 columns]
